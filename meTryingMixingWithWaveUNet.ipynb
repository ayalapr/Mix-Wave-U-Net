# %% [markdown]
# <a href="https://colab.research.google.com/github/ayalapr/Mix-Wave-U-Net/blob/master/meTryingMixingWithWaveUNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ayalapr/Mix-Wave-U-Net.git
# Out:
# Cloning into 'Mix-Wave-U-Net'...
# remote: Enumerating objects: 437, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 437 (delta 6), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (437/437), 29.79 MiB | 24.74 MiB/s, done.
# Resolving deltas: 100% (236/236), done.

# %%
# !pip install numba==0.48
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 20.2 MB 7.0 MB/s
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires numpy>=1.18.5, but you have numpy 1.18.3 which is incompatible.
# ...

# %%
! pip install -r Mix-Wave-U-Net/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 20.2 MB 7.2 MB/s
# ...
#      |████████████████████████████████| 90 kB 9.1 MB/s
# ...
#      |████████████████████████████████| 410.9 MB 28 kB/s
# ...
#      |████████████████████████████████| 1.6 MB 32.1 MB/s
# ...
#      |████████████████████████████████| 5.7 MB 20.4 MB/s
# ...
#      |████████████████████████████████| 99 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 170 kB 47.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 503 kB 48.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
#   Created wheel for sacred: filename=sacred-0.8.1-py2.py3-none-any.whl size=105034 sha256=1d2c66459e801daf6e844b0393f9a5810189c53338fe714fe0defdcda4c4556e
#   Stored in directory: /root/.cache/pip/wheels/3c/ac/e1/2f746c47edc95a1cf43119706c787efd9c307a8b3d4a649308
# ...

# %%
! python  Mix-Wave-U-Net/Training.py with cfg.context_dry
# Out:
# Training dry model
# WARNING - Waveunet Training - No observers have been added to this run
# INFO - Waveunet Training - Running command 'run'
# INFO - Waveunet Training - Started
# SCRIPT START
# EPOCH: 0
# input shape: [    16 121843      8] - output shape: [   16 89093     2]
# Preparing dataset! This could take a while...
# Writing train partition...
# Reading song
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# Reading song
# Reading song
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# Reading song
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
